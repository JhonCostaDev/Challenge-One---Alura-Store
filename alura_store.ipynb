# %%
# Importação da biblioteca Pandas
import pandas as pd

# Atribuindo a localização dos arquivos a variáveis
path_csv_loja_1 = '/home/jonathan/Documents/GitHub/Challenge-One---Alura-Store/data/loja_1.csv'
path_csv_loja_2 = '/home/jonathan/Documents/GitHub/Challenge-One---Alura-Store/data/loja_2.csv'
path_csv_loja_3 = '/home/jonathan/Documents/GitHub/Challenge-One---Alura-Store/data/loja_3.csv'
path_csv_loja_4 = '/home/jonathan/Documents/GitHub/Challenge-One---Alura-Store/data/loja_4.csv'

# %%
# Carregar em dataframes Pandas
loja_1 = pd.read_csv(path_csv_loja_1)
loja_2 = pd.read_csv(path_csv_loja_2)
loja_3 = pd.read_csv(path_csv_loja_3)
loja_4 = pd.read_csv(path_csv_loja_4)

# %%
loja_1.describe()#.keys()
# Out:
#              Preço        Frete  Avaliação da compra  Quantidade de parcelas  \
# count  2359.000000  2359.000000          2359.000000             2359.000000
# mean    650.491361    34.691805             3.976685                2.943196
# std     819.582778    43.814183             1.415370                2.819897
# min      10.070000     0.000000             1.000000                1.000000
# 25%      74.345000     4.141783             3.000000                1.000000
# 50%     313.750000    16.498835             5.000000                1.000000
# 75%     904.130000    48.050074             5.000000                4.000000
# max    3969.380000   214.377060             5.000000               24.000000
#
#                lat          lon
# count  2359.000000  2359.000000
# mean    -20.763366   -47.349385
# std       5.372400     4.183180
# min     -30.170000   -70.550000
# 25%     -22.250000   -48.790000
# 50%     -22.190000   -48.790000
# 75%     -18.100000   -44.380000
# ...
